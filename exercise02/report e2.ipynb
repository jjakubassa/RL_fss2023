# %% [raw]
# ---
# title: "Untitled"
# format: revealjs
# ---

# %% [markdown]
# ## Setup

# %%
from exercise02_v2 import *
from IPython.display import Image

# %%
epsilon = 0.1
alpha = 0.1
nr_episodes = 10_000
max_t = 400
gamma = 0.9999

# %% [markdown]
# setup enviroments

# %%
env_frozenlake_small = gym.make(
    "FrozenLake-v1", map_name="4x4", is_slippery=False, render_mode="rgb_array"
)
env_frozenlake_small_slippery = gym.make(
    "FrozenLake-v1", map_name="4x4", is_slippery=True, render_mode="rgb_array"
)
env_frozenlake_medium = gym.make(
    "FrozenLake-v1", map_name="8x8", is_slippery=False, render_mode="rgb_array"
)
env_frozenlake_medium_slippery = gym.make(
    "FrozenLake-v1", map_name="8x8", is_slippery=True, render_mode="rgb_array"
)
env_blackjack = FlattenedObservationWrapper(
    gym.make("Blackjack-v1", render_mode="rgb_array")
)

# %%
def mc_frozenlake(env, name):
    MC_policy = MCOffPolicyControl(
            env, epsilon=epsilon, nr_episodes=nr_episodes, max_t=max_t, gamma=gamma
        )
    plt.show()
    print(
        "Mean episode reward from MC trained policy on",
        name,
        ": ",
        evaluate_greedy_policy(env, MC_policy),
    )

# %% [markdown]
# ## MC Off-Policy Control

# %% [markdown]
# ### frozenlake small

# %%
env = env_frozenlake_small
name = "frozenlake_small"
gif_name = "../exercise02/" + name + "_MC.gif"

# %%
mc_frozenlake(env, name)
# Out:
# Training:   0%|          | 0/10000 [00:00<?, ?episodes/s]/Users/jonas/mambaforge/envs/MMDS/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/jonas/mambaforge/envs/MMDS/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Training: 100%|██████████| 10000/10000 [00:00<00:00, 10338.99episodes/s, episode return=0.90, episode length=6.21, backtrack=nan%]
# Mean episode reward from MC trained policy on frozenlake_small :  1.0

# %%
# %%capture
render_FrozenLake(env, MC_policy, name + "_MC.gif", max_t=100)

# %%
Image(filename=gif_name)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### frozenlake small slippery

# %%
env = env_frozenlake_small_slippery
name = "frozenlake_small_slippery"
gif_name = "../exercise02/" + name + "_MC.gif"

# %%
mc_frozenlake(env, name)
# Out:
# Training:   0%|          | 0/10000 [00:00<?, ?episodes/s]/Users/jonas/mambaforge/envs/MMDS/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/jonas/mambaforge/envs/MMDS/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Training: 100%|██████████| 10000/10000 [00:03<00:00, 3030.77episodes/s, episode return=0.21, episode length=37.19, backtrack=nan%]
# Mean episode reward from MC trained policy on frozenlake_small_slippery :  0.288

# %%
# %%capture
render_FrozenLake(env, MC_policy, name + "_MC.gif", max_t=100)

# %%
Image(filename= gif_name)

# %% [markdown]
# ### frozenlake medium

# %% [markdown]
# ### frozenlake medium slippery

# %% [markdown]
# ## Sarsa

# %% [markdown]
# ### frozenlake small

# %% [markdown]
# ### frozenlake small slippery

# %% [markdown]
# ### frozenlake medium

# %% [markdown]
# ### frozenlake medium slippery
